# %% [markdown]
# # Iris Project

# %% [markdown]
# ## 1) Przygotowanie do analizu

# %% [markdown]
# ### Od razu importuemy wszystkie urzywany biblioteki

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import sklearn as sk

# %% [markdown]
# ### Wczytywamy zbiór danych

# %%
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.csv"

# Dodajemy jeszcze nazwy do kolumn, dla lepszej vizualizacji danych
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']

# Wczytujemy dane do obiekta DataFrame biblioteki pandas
dataset = pd.read_csv(url, names=names)
print(type(dataset))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ##  2) Podsumowanie zbiora danych (za pomocą Pandas)

# %% [markdown]
# ![iris-data](assets/iris-petal-sepal.png)

# %% [markdown]
# ### Rozmiary zbióra danych

# %%
print(dataset.shape)
# To pomaga nam podejmować poprawne decyzji
# Out:
# (150, 5)

# %% [markdown]
# ### Pierwszy 30 rekordów z tego zbioóra danych

# %%
print(dataset.head(30))
# Żeby zrozumieć z jakimi danymy pracujemy miło będzie zobaczyć kilkadziesiąt danych
# Out:
#     sepal-length  sepal-width  petal-length  petal-width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# 12           4.8          3.0           1.4          0.1  Iris-setosa
# 13           4.3          3.0           1.1          0.1  Iris-setosa
# 14           5.8          4.0           1.2          0.2  Iris-setosa
# 15           5.7          4.4           1.5          0.4  Iris-setosa
# 16           5.4          3.9           1.3          0.4  Iris-setosa
# 17           5.1          3.5           1.4          0.3  Iris-setosa
# 18           5.7          3.8           1.7          0.3  Iris-setosa
# 19           5.1          3.8           1.5          0.3  Iris-setosa
# 20           5.4          3.4           1.7          0.2  Iris-setosa
# 21           5.1          3.7           1.5          0.4  Iris-setosa
# 22           4.6          3.6           1.0          0.2  Iris-setosa
# 23           5.1          3.3           1.7          0.5  Iris-setosa
# 24           4.8          3.4           1.9          0.2  Iris-setosa
# 25           5.0          3.0           1.6          0.2  Iris-setosa
# 26           5.0          3.4           1.6          0.4  Iris-setosa
# 27           5.2          3.5           1.5          0.2  Iris-setosa
# 28           5.2          3.4           1.4          0.2  Iris-setosa
# 29           4.7          3.2           1.6          0.2  Iris-setosa

# %% [markdown]
# ### Ogólna statystyka tego zbióra danych

# %%
print(dataset.describe())
# Out:
#        sepal-length  sepal-width  petal-length  petal-width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Z tej szybkiej statystyki od razu możemy zwrócić uwagę, że dlugość kwiat więciej niż szerokość i że płatki sepala są więcej niż płatki petala. Również możemy zauważić, że długość petala szybko rośną, więc ma dużą amplitudę w poruwnaniu z sepalem.

# %% [markdown]
# ### Rozkład klas

# %%
print(dataset.groupby("class").size())
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# Widzimy, że mamy 3 róznych rodzaja irusu

# %% [markdown]
# ## 3) Vizualizacja danych (za pomocą matplotlib)

# %% [markdown]
# ### Wykresy jednoczynnikowe

# %%
# plots
dataset.plot(kind="box", subplots=True, layout=(2, 2), figsize=(15, 15))
mpl.pyplot.show()

# %% [markdown]
# Jak pisałem wcześniej, amplituda jest znacznie większa w petal, co jest wyraźnie widoczne na wykresie.
# Również teraz możemy powiedzieć, że płatki petala mają średnio dłuższe płatki niż krótkie.

# %%
dataset.plot(kind="area", subplots=True, layout=(2, 2), figsize=(15, 15))
mpl.pyplot.show()

# %% [markdown]
# Tu również widoczne, że amplituda petala dużo zmianina

# %%
# histograms
dataset.hist(figsize=(15, 15))
mpl.pyplot.show()

# %% [markdown]
# Z histograma widoczne, jakich irisów więcej: z długimi i szerokimi płatkami lub krótkimi i wąskimi.
# N.p. Petal ma więcej małych płatków podczas Sepal ma więcej średnich rozmiarów.

# %% [markdown]
# ### Wykresy wielowymiarowe

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(dataset, figsize=(15, 15), alpha=0.3, diagonal='kde')
mpl.pyplot.show()

# %% [markdown]
# ## 4) Wybraniu algorytmu

# %% [markdown]
# ### Tworzenie zestawa sprawdzania poprawności

# %%
import sklearn.model_selection
array = dataset.values
X = array[:, 0:4]
Y = array[:, 4]
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=0.20, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# Spot Check Algorithms
models = []
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto')))
# evaluate each model in turn
results = []
names = []
for name, model in models:
	kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
	cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')
	results.append(cv_results)
	names.append(name)
	print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# LR: 0.941667 (0.065085)
# LDA: 0.975000 (0.038188)
# KNN: 0.958333 (0.041667)
# CART: 0.941667 (0.053359)
# NB: 0.950000 (0.055277)
# SVM: 0.983333 (0.033333)
